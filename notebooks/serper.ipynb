# %%
import requests

# %%
API_KEY = "66c2a8b8558911d235a1e1d1d44f4f3ded46cc17"  # Replace with your Serper API key

# %%
SEARCH_QUERY = "fish anatomy"


def search_youtube(query):
    url = "https://google.serper.dev/videos"
    headers = {"X-API-KEY": API_KEY, "Content-Type": "application/json"}
    payload = {"q": query}

    response = requests.post(url, json=payload, headers=headers)
    
    if response.status_code == 200:
        results = response.json()
        return results.get("videos", [])
    else:
        print(f"Error: {response.status_code}, {response.text}")
        return []

# Run search
videos = search_youtube(SEARCH_QUERY)

# Print results
for video in videos[:5]:  # Show top 5 results
    print(video)
    if video['source'] == 'YouTube':
        print(f"Title: {video['title']}")
        print(f"URL: {video['link']}")
        print(video)
    # print(f"Channel: {video['channelName']}")
    # print(f"Published: {video['date']}")
    print("-" * 50)
# Out:
# {'title': 'Fish Anatomy', 'link': 'https://www.youtube.com/watch?v=BE9QIaP7sIU', 'snippet': 'Kids learn about the basic anatomical characteristics shared by most types of fish. This video is part of the ¨What´s a fish?', 'imageUrl': 'https://i.ytimg.com/vi/BE9QIaP7sIU/mqdefault.jpg?sqp=-oaymwEFCJQBEFM&rs=AMzJL3lIHZWQAusdykzyBW66pSB7L7xL4w', 'videoUrl': 'https://encrypted-vtbn0.gstatic.com/video?q=tbn:ANd9GcQaX2piZd3_GY-VPzQ0uOu5BNDwtZPR6pSIIA', 'duration': '6:46', 'source': 'YouTube', 'channel': 'Smithsonian Marine Station', 'date': 'Jun 8, 2020', 'position': 1}
# Title: Fish Anatomy
# URL: https://www.youtube.com/watch?v=BE9QIaP7sIU
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi

GEMINI_API_KEY = "AIzaSyANZk0vRzfwXxAKXGQxqmVvKZVnYF8RTjQ"
video_id = 'EcTW1mP-OZU'
ytt_api = YouTubeTranscriptApi()
fetched_transcript = ytt_api.fetch(video_id, languages=['fr'])
raw_transcript = "\n".join([snippet.text for snippet in fetched_transcript.snippets])
raw_transcript
# Out:
# "chez Décathlon ils sont dit ben en fait\nil y a quand même un domaine qu'on est\npas en train de d'accompagner d'un point\nde vue data c'est toute la partie r on a\nla chance d'avoir une vision stratégique\nà 3 4 5 ans et le but c'est se dire mais\ncomment est-ce que nous domaine RH et\néquipe hipolanalytique on fait pour y\ncontribuer en magasin demain il y un\narrêt maladie sur le rayon pêche il faut\nque le leader il soit en capacité de\nsavoir qui est formé sur la pêche dans\nce magasin si je te mets un vendeur du\nrayon ski je suis pas sûr qu'on fasse le\nmeilleur chiffre d'affaires du jour\naujourd'hui je reçois Fabien qui est\npeople Analytics manager chez dcathlon\nil va nous parler de son plus gros\nchallenge de ces dernières années à\nsavoir lancer l'équipe people Analytics\nde Decathlon c'est une tendance qui\némerge depuis quelques années les grands\ngroupes créent des équipes data\nAnalytics dédié au sujet des ressources\nhumaines et dcathlon est l'un des\npremiers que 
# ...

# %%
from google.cloud import storage

def upload_to_gcs(bucket_name, source_file_path, destination_blob_name):
    """Uploads a file to a Google Cloud Storage bucket."""

    # Initialize a GCS client
    client = storage.Client()

    # Get the bucket
    bucket = client.bucket(bucket_name)

    # Create a blob (GCS object)
    blob = bucket.blob(destination_blob_name)

    # Upload the file
    blob.upload_from_filename(source_file_path)

    print(f"File {source_file_path} uploaded to gs://{bucket_name}/{destination_blob_name}")

with open('test.txt', 'w') as f:
    f.write('test')
# Example usage
upload_to_gcs("bucket-agentic-era-hack", "test.txt", "uploaded-file.txt")
# Out:
# File test.txt uploaded to gs://bucket-agentic-era-hack/uploaded-file.txt
